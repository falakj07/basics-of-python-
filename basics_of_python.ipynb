# %% [markdown]
# <a href="https://colab.research.google.com/github/falakj07/basics-of-python-/blob/main/basics_of_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Many Statements
print("Hello World ")
print("Have a good day")
print("Learning a Python is fun!")
# Out:
# Hello World
# Have a good day
# Learning a Python is fun!

# %%
print("Hello world.", end=" ")
print("I will print on the same line .")
# Out:
# Hello world. I will print on the same line .

# %%
#Print numbers
a = 3
print(a)
print(358)
print(500.200)
# Out:
# 3
# 358
# 500.2

# %%
# Understanding data type
x= 10
y = 3.14
z = "Python"
A= True
C = 3+2j

print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# Many Values to MUltiple variables
x,y,z = "Orange","Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
# Variables
x = 5
y = "Hello, world!"

# %%
# Case sensitive
a = 4
A = "Sally"

print(a)
print(A)
# Out:
# 4
# Sally

# %%
# Basic Arithmetic Operations
a = 10
b = 5

print("Addition =", a + b)
# Out:
# Addition = 15

# %%
print("Subtraction =", a - b)
# Out:
# Subtraction = 5

# %%
print("Multiplication =", a * b)
# Out:
# Multiplication = 50

# %%
print("Division =", a / b)
# Out:
# Division = 2.0

# %%
# Taking Input from User
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Name:", name)
print("Age:", age)
# Out:
# Enter your name: falak
# Enter your age: 18
# Name: falak
# Age: 18

# %%
# Write a program for Simple Calculator
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Sum =", a + b)
print("Difference =", a - b)
print("Product =", a * b)
print("Quotient =", a / b)
# Out:
# Enter first number: 20
# Enter second number: 30
# Sum = 50
# Difference = -10
# Product = 600
# Quotient = 0.6666666666666666

# %%
# Take marks from 5 studetns and find sum and average
a = int(input("Enter your marks: "))
b = int(input("Enter your marks: "))
c = int(input("Enter your marks: "))
d = int(input("Enter your marks: "))
e = int(input("Enter your marks: "))
print("Sum= ", a+b+c+d+e)
print("Average= ", (a+b+c+d+e)/5)
# Out:
# Enter your marks: 54
# Enter your marks: 46
# Enter your marks: 49
# Enter your marks: 53
# Enter your marks: 50
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3227229818.py in <cell line: 0>()
#       5 d = int(input("Enter your marks: "))
#       6 e = int(input("Enter your marks: "))
# ----> 7 print("Sum= ", a+b+c+d+e)
#       8 print("Average= ", (a+b+c+d+e)/5)
#
# TypeError: 'tuple' object is not callable

# %%
#Find area and perimeter of rectangle
l = int(input("Enter length of rectangle:"))
b = int(input("Enter breadth of rectangle:"))
area = l*b
perimeter = 2*(l+b)
print("Area of circle=", area)
print("Perimeter of circle=", perimeter)
# Out:
# Enter length of rectangle:10
# Enter breadth of rectangle:20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2899293023.py in <cell line: 0>()
#       4 area = l*b
#       5 perimeter = 2*(l+b)
# ----> 6 print("Area of circle=", area)
#       7 print("Perimeter of circle=", perimeter)
#       8
#
# TypeError: 'tuple' object is not callable

# %%
# Write a Python program to find the area of a circle.
r = float(input("Enter radius: "))
area = 3.14 * r * r
print("Area of circle =", area)
# Out:
# Enter radius: 14
# Area of circle = 615.44

# %% [markdown]
# # New Section
